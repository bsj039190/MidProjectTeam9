# %% [markdown]
# # 이상치 제거 및 데이터 정제

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_PATH = '/content/drive/MyDrive/멋사/mid project/'

# %%
import pandas as pd
import numpy as np

# %%
org_df = pd.read_csv(DATA_PATH + 'train.csv')
org_df
# Out:
#                    PBLPRFR_NM PBLPRFR_PLACE_NM  PBLPRFR_DE  PBLPRFR_TIME  \
# 0  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀    20230321        193000
# 1  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀    20230321        193000
# 2  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀    20230321        193000
# 3  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀    20230321        193000
# 4  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀    20230321        193000
#
#   GENRE_NM                             PRC_CN  \
# 0       합창  R석 30000원 / S석 20000원 / A석 10000원
# 1       합창  R석 30000원 / S석 20000원 / A석 10000원
# 2       합창  R석 30000원 / S석 20000원 / A석 10000원
# 3       합창  R석 30000원 / S석 20000원 / A석 10000원
# 4       합창  R석 30000원 / S석 20000원 / A석 10000원
#
#                                             HMPG_URL  SETLE_DE  SETLE_TIME  \
# 0  https://www.sac.or.kr/site/main/show/show_view...  20230308       70000
# 1  https://www.sac.or.kr/site/main/show/show_view...  20230221      190000
# 2  https://www.sac.or.kr/site/main/show/show_view...  20230228       10000
# 3  https://www.sac.or.kr/site/main/show/show_view...  20230226      100000
# 4  https://www.sac.or.kr/site/main/show/show_view...  20230320      230000
#
#      DSCNT_CN  SETLE_PRICE MBER_GRAD_NM BN_VALUE SEXDSTN_VALUE OC_AREA_NM  \
# 0       기타 할인      24000.0           무료      50대             F         경기
# 1       기타 할인      10000.0           블루      60대             M         서울
# 2       기타 할인       8000.0           무료      60대             M         서울
# 3       기타 할인      24000.0           무료      40대             M         서울
# 4  골드회원 할인40%      18000.0           골드      60대             F         서울
#
#   RFN_AT
# 0      N
# 1      N
# 2      N
# 3      N
# 4      N

# %% [markdown]
# ### 좌석수 조인

# %%
hall_df = pd.read_csv(DATA_PATH + '공연시설별좌석수.csv')
hall_df.head()
# Out:
#   PBLPRFR_PLACE_NM  총판매석  일반판매석  장애인석  OP석  판매유보석
# 0          CJ 토월극장  1004    842    10   63     89
# 1           IBK챔버홀   600    594     6    0      0
# 2            리사이틀홀   354    350     4    0      0
# 3            오페라극장  2283   1925    20   48    290
# 4            인춘아트홀   100     98     2    0      0

# %%
# 원본에 공연장 정보 조인
org_hall_df = pd.merge(org_df, hall_df, on='PBLPRFR_PLACE_NM', how='left')
org_hall_df.head()
# Out:
#                    PBLPRFR_NM PBLPRFR_PLACE_NM  PBLPRFR_DE  PBLPRFR_TIME  \
# 0  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀    20230321        193000
# 1  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀    20230321        193000
# 2  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀    20230321        193000
# 3  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀    20230321        193000
# 4  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀    20230321        193000
#
#   GENRE_NM                             PRC_CN  \
# 0       합창  R석 30000원 / S석 20000원 / A석 10000원
# 1       합창  R석 30000원 / S석 20000원 / A석 10000원
# 2       합창  R석 30000원 / S석 20000원 / A석 10000원
# 3       합창  R석 30000원 / S석 20000원 / A석 10000원
# 4       합창  R석 30000원 / S석 20000원 / A석 10000원
#
#                                             HMPG_URL  SETLE_DE  SETLE_TIME  \
# 0  https://www.sac.or.kr/site/main/show/show_view...  20230308       70000
# 1  https://www.sac.or.kr/site/main/show/show_view...  20230221      190000
# 2  https://www.sac.or.kr/site/main/show/show_view...  20230228       10000
# 3  https://www.sac.or.kr/site/main/show/show_view...  20230226      100000
# 4  https://www.sac.or.kr/site/main/show/show_view...  20230320      230000
#
#      DSCNT_CN  ...  MBER_GRAD_NM BN_VALUE SEXDSTN_VALUE OC_AREA_NM RFN_AT  \
# 0       기타 할인  ...            무료      50대             F         경기      N
# 1       기타 할인  ...            블루      60대             M         서울      N
# 2       기타 할인  ...            무료      60대             M         서울      N
# 3       기타 할인  ...            무료      40대             M         서울      N
# 4  골드회원 할인40%  ...            골드      60대             F         서울      N
#
#      총판매석   일반판매석  장애인석  OP석  판매유보석
# 0  2505.0  2481.0  24.0  0.0    0.0
# 1  2505.0  2481.0  24.0  0.0    0.0
# 2  2505.0  2481.0  24.0  0.0    0.0
# 3  2505.0  2481.0  24.0  0.0    0.0
# 4  2505.0  2481.0  24.0  0.0    0.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### URL 정보 삭제

# %%
org_hall_df.drop('HMPG_URL', axis=1, inplace=True)
org_hall_df.head()
# Out:
#                    PBLPRFR_NM PBLPRFR_PLACE_NM  PBLPRFR_DE  PBLPRFR_TIME  \
# 0  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀    20230321        193000
# 1  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀    20230321        193000
# 2  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀    20230321        193000
# 3  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀    20230321        193000
# 4  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀    20230321        193000
#
#   GENRE_NM                             PRC_CN  SETLE_DE  SETLE_TIME  \
# 0       합창  R석 30000원 / S석 20000원 / A석 10000원  20230308       70000
# 1       합창  R석 30000원 / S석 20000원 / A석 10000원  20230221      190000
# 2       합창  R석 30000원 / S석 20000원 / A석 10000원  20230228       10000
# 3       합창  R석 30000원 / S석 20000원 / A석 10000원  20230226      100000
# 4       합창  R석 30000원 / S석 20000원 / A석 10000원  20230320      230000
#
#      DSCNT_CN  SETLE_PRICE MBER_GRAD_NM BN_VALUE SEXDSTN_VALUE OC_AREA_NM  \
# 0       기타 할인      24000.0           무료      50대             F         경기
# 1       기타 할인      10000.0           블루      60대             M         서울
# 2       기타 할인       8000.0           무료      60대             M         서울
# 3       기타 할인      24000.0           무료      40대             M         서울
# 4  골드회원 할인40%      18000.0           골드      60대             F         서울
#
#   RFN_AT    총판매석   일반판매석  장애인석  OP석  판매유보석
# 0      N  2505.0  2481.0  24.0  0.0    0.0
# 1      N  2505.0  2481.0  24.0  0.0    0.0
# 2      N  2505.0  2481.0  24.0  0.0    0.0
# 3      N  2505.0  2481.0  24.0  0.0    0.0
# 4      N  2505.0  2481.0  24.0  0.0    0.0

# %% [markdown]
# - 나이값은 '대' 를 빼고 나이값만 int로
# - 성별은 M -> 0, F -> 1
# - PBLPRFR_DE는 date값으로

# %%
org_hall_df['BN_VALUE'] = org_hall_df['BN_VALUE'].str.extract('(\d+)').astype(float).fillna(0).astype(int)
org_hall_df['SEXDSTN_VALUE'] = org_hall_df['SEXDSTN_VALUE'].replace({'M': 0, 'F': 1})
org_hall_df['PBLPRFR_DE'] = pd.to_datetime(org_hall_df['PBLPRFR_DE'], format='%Y%m%d', errors='coerce')
org_hall_df.head()
# Out:
# <ipython-input-8-1835900a47a3>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   org_hall_df['SEXDSTN_VALUE'] = org_hall_df['SEXDSTN_VALUE'].replace({'M': 0, 'F': 1})
#                    PBLPRFR_NM PBLPRFR_PLACE_NM PBLPRFR_DE  PBLPRFR_TIME  \
# 0  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
# 1  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
# 2  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
# 3  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
# 4  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
#
#   GENRE_NM                             PRC_CN  SETLE_DE  SETLE_TIME  \
# 0       합창  R석 30000원 / S석 20000원 / A석 10000원  20230308       70000
# 1       합창  R석 30000원 / S석 20000원 / A석 10000원  20230221      190000
# 2       합창  R석 30000원 / S석 20000원 / A석 10000원  20230228       10000
# 3       합창  R석 30000원 / S석 20000원 / A석 10000원  20230226      100000
# 4       합창  R석 30000원 / S석 20000원 / A석 10000원  20230320      230000
#
#      DSCNT_CN  SETLE_PRICE MBER_GRAD_NM  BN_VALUE  SEXDSTN_VALUE OC_AREA_NM  \
# 0       기타 할인      24000.0           무료        50            1.0         경기
# 1       기타 할인      10000.0           블루        60            0.0         서울
# 2       기타 할인       8000.0           무료        60            0.0         서울
# 3       기타 할인      24000.0           무료        40            0.0         서울
# 4  골드회원 할인40%      18000.0           골드        60            1.0         서울
#
#   RFN_AT    총판매석   일반판매석  장애인석  OP석  판매유보석
# 0      N  2505.0  2481.0  24.0  0.0    0.0
# 1      N  2505.0  2481.0  24.0  0.0    0.0
# 2      N  2505.0  2481.0  24.0  0.0    0.0
# 3      N  2505.0  2481.0  24.0  0.0    0.0
# 4      N  2505.0  2481.0  24.0  0.0    0.0

# %%
# prompt: org_hall_df[SEXDSTN_VALUE]값들을 int로 변환

# SEXDSTN_VALUE 컬럼의 값을 int로 변환 (숫자로 변환 가능한 값만 변환)
org_hall_df['SEXDSTN_VALUE'] = pd.to_numeric(org_hall_df['SEXDSTN_VALUE'], errors='coerce').fillna(1).astype(int)

# %%
org_hall_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3664663 entries, 0 to 3664662
# Data columns (total 20 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   PBLPRFR_NM        object
#  1   PBLPRFR_PLACE_NM  object
#  2   PBLPRFR_DE        datetime64[ns]
#  3   PBLPRFR_TIME      int64
#  4   GENRE_NM          object
#  5   PRC_CN            object
#  6   SETLE_DE          int64
#  7   SETLE_TIME        int64
#  8   DSCNT_CN          object
#  9   SETLE_PRICE       float64
#  10  MBER_GRAD_NM      object
#  11  BN_VALUE          int64
#  12  SEXDSTN_VALUE     int64
#  13  OC_AREA_NM        object
#  14  RFN_AT            object
#  15  총판매석              float64
#  16  일반판매석             float64
#  17  장애인석              float64
#  18  OP석               float64
#  19  판매유보석             float64
# dtypes: datetime64[ns](1), float64(6), int64(5), object(8)
# memory usage: 559.2+ MB

# %%
org_hall_df.head()
# Out:
#                    PBLPRFR_NM PBLPRFR_PLACE_NM PBLPRFR_DE  PBLPRFR_TIME  \
# 0  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
# 1  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
# 2  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
# 3  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
# 4  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
#
#   GENRE_NM                             PRC_CN  SETLE_DE  SETLE_TIME  \
# 0       합창  R석 30000원 / S석 20000원 / A석 10000원  20230308       70000
# 1       합창  R석 30000원 / S석 20000원 / A석 10000원  20230221      190000
# 2       합창  R석 30000원 / S석 20000원 / A석 10000원  20230228       10000
# 3       합창  R석 30000원 / S석 20000원 / A석 10000원  20230226      100000
# 4       합창  R석 30000원 / S석 20000원 / A석 10000원  20230320      230000
#
#      DSCNT_CN  SETLE_PRICE MBER_GRAD_NM  BN_VALUE  SEXDSTN_VALUE OC_AREA_NM  \
# 0       기타 할인      24000.0           무료        50              1         경기
# 1       기타 할인      10000.0           블루        60              0         서울
# 2       기타 할인       8000.0           무료        60              0         서울
# 3       기타 할인      24000.0           무료        40              0         서울
# 4  골드회원 할인40%      18000.0           골드        60              1         서울
#
#   RFN_AT    총판매석   일반판매석  장애인석  OP석  판매유보석
# 0      N  2505.0  2481.0  24.0  0.0    0.0
# 1      N  2505.0  2481.0  24.0  0.0    0.0
# 2      N  2505.0  2481.0  24.0  0.0    0.0
# 3      N  2505.0  2481.0  24.0  0.0    0.0
# 4      N  2505.0  2481.0  24.0  0.0    0.0

# %% [markdown]
# ### 크롤링 데이터 가져오기

# %%
delete_df = pd.read_csv(DATA_PATH + 'crolling_result.csv')
delete_df
# Out:
#                       PBLPRFR_NM PBLPRFR_PLACE_NM  PBLPRFR_DE    RFN_AT  \
# 0          2015 CBS갈라콘서트 아름다운 열정             콘서트홀  2015-03-16  0.804734
# 1      2015 The One&Only 문화나눔콘서트           IBK챔버홀  2015-11-18  0.891892
# 2           2015 앙상블 뉴화인아트 정기연주회           IBK챔버홀  2015-06-26  0.963855
# 3    2015 예술의전당 클래식 스타 시리즈 - 송영훈           IBK챔버홀  2015-12-18  0.846599
# 4      2015 제33회 대한민국국제음악제(11.2)             콘서트홀  2015-11-02  0.800000
# ..                           ...              ...         ...       ...
# 342                 홍종화 바이올린 독주회           IBK챔버홀  2015-10-05  1.000000
# 343  화음챔버오케스트라 현대음악 렉처 콘서트 시리즈 Ⅰ           IBK챔버홀  2020-03-05  1.000000
# 344   화음챔버오케스트라 현대음악 렉처콘서트 시리즈 Ⅲ           IBK챔버홀  2020-12-13  1.000000
# 345        화음챔버오케스트라의 현대음악 시리즈 Ⅲ           IBK챔버홀  2020-09-03  1.000000
# 346         화음쳄버오케스트라 제39회 정기연주회           IBK챔버홀  2015-07-09  0.910853
#
#      max_value result
# 0     0.776776  False
# 1     0.732620  False
# 2     0.732620  False
# 3     0.732620  False
# 4     0.776776  False
# ..         ...    ...
# 342   0.732620  False
# 343   0.732620    NaN
# 344   0.732620    NaN
# 345   0.732620    NaN
# 346   0.732620  False
#
# [347 rows x 6 columns]

# %% [markdown]
# - True, None값 골라내기

# %%
mask = (delete_df['result'] == False)
delete_df = delete_df[~mask]
delete_df.head()
# Out:
#                           PBLPRFR_NM PBLPRFR_PLACE_NM  PBLPRFR_DE    RFN_AT  \
# 10                  2016 서울향의 합창 교향곡             콘서트홀  2016-12-28  0.800792
# 11            2016 서울향의 합창, 또 하나의 환희             콘서트홀  2016-12-29  0.834297
# 16          2018 일리야 라쉬코프스키 피아노 리사이틀           IBK챔버홀  2018-12-11  0.926829
# 17        2020 교향악축제 - KBS교향악단 (4.2)             콘서트홀  2020-04-02  0.946691
# 19  2020 교향악축제 - 경기 필하모닉오케스트라 (4.11)             콘서트홀  2020-04-11  0.880460
#
#     max_value result
# 10   0.776776    NaN
# 11   0.776776    NaN
# 16   0.732620    NaN
# 17   0.776776    NaN
# 19   0.776776    NaN

# %%
len(delete_df), len(org_hall_df) # 원래는 142, 3664663
# Out:
# (142, 3664663)

# %%
d_org_df = org_hall_df.copy()
d_org_df
# Out:
#                          PBLPRFR_NM PBLPRFR_PLACE_NM PBLPRFR_DE  PBLPRFR_TIME  \
# 0        국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
# 1        국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
# 2        국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
# 3        국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
# 4        국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
# ...                             ...              ...        ...           ...
# 3664658      로열 콘세르트허바우 오케스트라(4.23)             콘서트홀 2015-04-23        200000
# 3664659      로열 콘세르트허바우 오케스트라(4.23)             콘서트홀 2015-04-23        200000
# 3664660      로열 콘세르트허바우 오케스트라(4.23)             콘서트홀 2015-04-23        200000
# 3664661      로열 콘세르트허바우 오케스트라(4.23)             콘서트홀 2015-04-23        200000
# 3664662      로열 콘세르트허바우 오케스트라(4.23)             콘서트홀 2015-04-23        200000
#
#         GENRE_NM                                          PRC_CN  SETLE_DE  \
# 0             합창               R석 30000원 / S석 20000원 / A석 10000원  20230308
# 1             합창               R석 30000원 / S석 20000원 / A석 10000원  20230221
# 2             합창               R석 30000원 / S석 20000원 / A석 10000원  20230228
# 3             합창               R석 30000원 / S석 20000원 / A석 10000원  20230226
# 4             합창               R석 30000원 / S석 20000원 / A석 10000원  20230320
# ...          ...                                             ...       ...
# 3664658      클래식  R석 38만원 / S석 28만원 / A석 20만원 / B석 15만원 / C석 8만원  20141015
# 3664659      클래식  R석 38만원 / S석 28만원 / A석 20만원 / B석 15만원 / C석 8만원  20150326
# 3664660      클래식  R석 38만원 / S석 28만원 / A석 20만원 / B석 15만원 / C석 8만원  20150411
# 3664661      클래식  R석 38만원 / S석 28만원 / A석 20만원 / B석 15만원 / C석 8만원  20150411
# 3664662      클래식  R석 38만원 / S석 28만원 / A석 20만원 / B석 15만원 / C석 8만원  20150411
#
#          SETLE_TIME    DSCNT_CN  SETLE_PRICE MBER_GRAD_NM  BN_VALUE  \
# 0             70000       기타 할인      24000.0           무료        50
# 1            190000       기타 할인      10000.0           블루        60
# 2             10000       기타 할인       8000.0           무료        60
# 3            100000       기타 할인      24000.0           무료        40
# 4            230000  골드회원 할인40%      18000.0           골드        60
# ...             ...         ...          ...          ...       ...
# 3664658      100000       기타 할인      68000.0           골드        30
# 3664659       20000       기타 할인     150000.0           블루        50
# 3664660       30000       기타 할인     200000.0           블루        50
# 3664661       30000       기타 할인     200000.0           블루        50
# 3664662       30000       기타 할인     200000.0           블루        50
#
#          SEXDSTN_VALUE OC_AREA_NM RFN_AT    총판매석   일반판매석  장애인석  OP석  판매유보석
# 0                    1         경기      N  2505.0  2481.0  24.0  0.0    0.0
# 1                    0         서울      N  2505.0  2481.0  24.0  0.0    0.0
# 2                    0         서울      N  2505.0  2481.0  24.0  0.0    0.0
# 3                    0         서울      N  2505.0  2481.0  24.0  0.0    0.0
# 4                    1         서울      N  2505.0  2481.0  24.0  0.0    0.0
# ...                ...        ...    ...     ...     ...   ...  ...    ...
# 3664658              0         서울      N  2505.0  2481.0  24.0  0.0    0.0
# 3664659              1         서울      Y  2505.0  2481.0  24.0  0.0    0.0
# 3664660              1         서울      Y  2505.0  2481.0  24.0  0.0    0.0
# 3664661              1         서울      Y  2505.0  2481.0  24.0  0.0    0.0
# 3664662              1         서울      Y  2505.0  2481.0  24.0  0.0    0.0
#
# [3664663 rows x 20 columns]

# %% [markdown]
# - 환불여부 0, 1로 변환

# %%
# RFN에서 N = 0, Y = 1로 변환
d_org_df.RFN_AT = d_org_df.RFN_AT.replace({'N': 0, 'Y': 1})
d_org_df.head()
# Out:
# <ipython-input-72-3ba0039cdd30>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   d_org_df.RFN_AT = d_org_df.RFN_AT.replace({'N': 0, 'Y': 1})
#                    PBLPRFR_NM PBLPRFR_PLACE_NM PBLPRFR_DE  PBLPRFR_TIME  \
# 0  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
# 1  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
# 2  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
# 3  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
# 4  국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
#
#   GENRE_NM                             PRC_CN  SETLE_DE  SETLE_TIME  \
# 0       합창  R석 30000원 / S석 20000원 / A석 10000원  20230308       70000
# 1       합창  R석 30000원 / S석 20000원 / A석 10000원  20230221      190000
# 2       합창  R석 30000원 / S석 20000원 / A석 10000원  20230228       10000
# 3       합창  R석 30000원 / S석 20000원 / A석 10000원  20230226      100000
# 4       합창  R석 30000원 / S석 20000원 / A석 10000원  20230320      230000
#
#      DSCNT_CN  SETLE_PRICE MBER_GRAD_NM  BN_VALUE  SEXDSTN_VALUE OC_AREA_NM  \
# 0       기타 할인      24000.0           무료        50              1         경기
# 1       기타 할인      10000.0           블루        60              0         서울
# 2       기타 할인       8000.0           무료        60              0         서울
# 3       기타 할인      24000.0           무료        40              0         서울
# 4  골드회원 할인40%      18000.0           골드        60              1         서울
#
#    RFN_AT    총판매석   일반판매석  장애인석  OP석  판매유보석
# 0       0  2505.0  2481.0  24.0  0.0    0.0
# 1       0  2505.0  2481.0  24.0  0.0    0.0
# 2       0  2505.0  2481.0  24.0  0.0    0.0
# 3       0  2505.0  2481.0  24.0  0.0    0.0
# 4       0  2505.0  2481.0  24.0  0.0    0.0

# %%
#masking = d_org_df.merge(delete_df[['PBLPRFR_NM', 'PBLPRFR_DE']], on=['PBLPRFR_NM', 'PBLPRFR_DE'], how='inner')
delete_df['PBLPRFR_DE'] = pd.to_datetime(delete_df['PBLPRFR_DE'])
# Out:
# <ipython-input-73-22f566d101d6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   delete_df['PBLPRFR_DE'] = pd.to_datetime(delete_df['PBLPRFR_DE'])

# %% [markdown]
# ### 'PBLPRFR_NM', 'PBLPRFR_DE' 가 같은 행들 마스킹

# %%
masking = d_org_df.merge(delete_df[['PBLPRFR_NM', 'PBLPRFR_DE']], on=['PBLPRFR_NM', 'PBLPRFR_DE'], how='inner')

# %%
print(len(masking))
masking
# Out:
# 53523
#             PBLPRFR_NM PBLPRFR_PLACE_NM PBLPRFR_DE  PBLPRFR_TIME GENRE_NM  \
# 0                 레볼루션             콘서트홀 2023-03-01        170000      클래식
# 1                 레볼루션             콘서트홀 2023-03-01        170000      클래식
# 2                 레볼루션             콘서트홀 2023-03-01        170000      클래식
# 3                 레볼루션             콘서트홀 2023-03-01        170000      클래식
# 4                 레볼루션             콘서트홀 2023-03-01        170000      클래식
# ...                ...              ...        ...           ...      ...
# 53518  서울향의 바그너 II 발퀴레             콘서트홀 2015-05-20        190000      교향곡
# 53519       5월의 클래식 향연             콘서트홀 2015-05-16        200000      클래식
# 53520       5월의 클래식 향연             콘서트홀 2015-05-16        200000      클래식
# 53521       5월의 클래식 향연             콘서트홀 2015-05-16        200000      클래식
# 53522       5월의 클래식 향연             콘서트홀 2015-05-16        200000      클래식
#
#                                           PRC_CN  SETLE_DE  SETLE_TIME  \
# 0      R석 99000 / S석 77000 / A석 55000 / B석 33000  20230113      220000
# 1      R석 99000 / S석 77000 / A석 55000 / B석 33000  20230126      180000
# 2      R석 99000 / S석 77000 / A석 55000 / B석 33000  20230113      130000
# 3      R석 99000 / S석 77000 / A석 55000 / B석 33000  20230201      190000
# 4      R석 99000 / S석 77000 / A석 55000 / B석 33000  20230222           0
# ...                                          ...       ...         ...
# 53518         R 12만원/ S 9만원/ A 6만원/ B 3만원/ C 1만원  20141202      150000
# 53519            R 20만원 / S 12만원 / A 6만원 / B 3만원  20150425      140000
# 53520            R 20만원 / S 12만원 / A 6만원 / B 3만원  20150422      140000
# 53521            R 20만원 / S 12만원 / A 6만원 / B 3만원  20150422      140000
# 53522            R 20만원 / S 12만원 / A 6만원 / B 3만원  20150425      140000
#
#          DSCNT_CN  SETLE_PRICE MBER_GRAD_NM  BN_VALUE  SEXDSTN_VALUE  \
# 0      싹틔우미 할인40%      46200.0         싹틔우미        20              1
# 1      그린회원 할인10%      89100.0           그린        30              1
# 2      싹틔우미 할인40%      19800.0           골드        20              1
# 3           기타 할인      59400.0         싹틔우미        20              0
# 4           기타 할인      19800.0           골드        50              0
# ...           ...          ...          ...       ...            ...
# 53518       기타 할인      10000.0           무료        40              0
# 53519       기타 할인      18000.0         싹틔우미        20              1
# 53520       기타 할인     200000.0           무료        30              1
# 53521       기타 할인     200000.0           무료        30              1
# 53522       기타 할인      30000.0         싹틔우미        20              1
#
#       OC_AREA_NM  RFN_AT    총판매석   일반판매석  장애인석  OP석  판매유보석
# 0             충남       1  2505.0  2481.0  24.0  0.0    0.0
# 1             서울       1  2505.0  2481.0  24.0  0.0    0.0
# 2             서울       1  2505.0  2481.0  24.0  0.0    0.0
# 3             서울       1  2505.0  2481.0  24.0  0.0    0.0
# 4             경기       1  2505.0  2481.0  24.0  0.0    0.0
# ...          ...     ...     ...     ...   ...  ...    ...
# 53518         서울       1  2505.0  2481.0  24.0  0.0    0.0
# 53519         경기       1  2505.0  2481.0  24.0  0.0    0.0
# 53520         서울       1  2505.0  2481.0  24.0  0.0    0.0
# 53521         서울       1  2505.0  2481.0  24.0  0.0    0.0
# 53522         경기       1  2505.0  2481.0  24.0  0.0    0.0
#
# [53523 rows x 20 columns]

# %%
d_org_df = d_org_df[~d_org_df[['PBLPRFR_NM', 'PBLPRFR_DE']].apply(tuple, axis=1).isin(masking[['PBLPRFR_NM', 'PBLPRFR_DE']].apply(tuple, axis=1))]
d_org_df
# Out:
#                          PBLPRFR_NM PBLPRFR_PLACE_NM PBLPRFR_DE  PBLPRFR_TIME  \
# 0        국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
# 1        국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
# 2        국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
# 3        국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
# 4        국립합창단 창단 50주년 기념 <한국합창교향곡>             콘서트홀 2023-03-21        193000
# ...                             ...              ...        ...           ...
# 3664658      로열 콘세르트허바우 오케스트라(4.23)             콘서트홀 2015-04-23        200000
# 3664659      로열 콘세르트허바우 오케스트라(4.23)             콘서트홀 2015-04-23        200000
# 3664660      로열 콘세르트허바우 오케스트라(4.23)             콘서트홀 2015-04-23        200000
# 3664661      로열 콘세르트허바우 오케스트라(4.23)             콘서트홀 2015-04-23        200000
# 3664662      로열 콘세르트허바우 오케스트라(4.23)             콘서트홀 2015-04-23        200000
#
#         GENRE_NM                                          PRC_CN  SETLE_DE  \
# 0             합창               R석 30000원 / S석 20000원 / A석 10000원  20230308
# 1             합창               R석 30000원 / S석 20000원 / A석 10000원  20230221
# 2             합창               R석 30000원 / S석 20000원 / A석 10000원  20230228
# 3             합창               R석 30000원 / S석 20000원 / A석 10000원  20230226
# 4             합창               R석 30000원 / S석 20000원 / A석 10000원  20230320
# ...          ...                                             ...       ...
# 3664658      클래식  R석 38만원 / S석 28만원 / A석 20만원 / B석 15만원 / C석 8만원  20141015
# 3664659      클래식  R석 38만원 / S석 28만원 / A석 20만원 / B석 15만원 / C석 8만원  20150326
# 3664660      클래식  R석 38만원 / S석 28만원 / A석 20만원 / B석 15만원 / C석 8만원  20150411
# 3664661      클래식  R석 38만원 / S석 28만원 / A석 20만원 / B석 15만원 / C석 8만원  20150411
# 3664662      클래식  R석 38만원 / S석 28만원 / A석 20만원 / B석 15만원 / C석 8만원  20150411
#
#          SETLE_TIME    DSCNT_CN  SETLE_PRICE MBER_GRAD_NM  BN_VALUE  \
# 0             70000       기타 할인      24000.0           무료        50
# 1            190000       기타 할인      10000.0           블루        60
# 2             10000       기타 할인       8000.0           무료        60
# 3            100000       기타 할인      24000.0           무료        40
# 4            230000  골드회원 할인40%      18000.0           골드        60
# ...             ...         ...          ...          ...       ...
# 3664658      100000       기타 할인      68000.0           골드        30
# 3664659       20000       기타 할인     150000.0           블루        50
# 3664660       30000       기타 할인     200000.0           블루        50
# 3664661       30000       기타 할인     200000.0           블루        50
# 3664662       30000       기타 할인     200000.0           블루        50
#
#          SEXDSTN_VALUE OC_AREA_NM  RFN_AT    총판매석   일반판매석  장애인석  OP석  판매유보석
# 0                    1         경기       0  2505.0  2481.0  24.0  0.0    0.0
# 1                    0         서울       0  2505.0  2481.0  24.0  0.0    0.0
# 2                    0         서울       0  2505.0  2481.0  24.0  0.0    0.0
# 3                    0         서울       0  2505.0  2481.0  24.0  0.0    0.0
# 4                    1         서울       0  2505.0  2481.0  24.0  0.0    0.0
# ...                ...        ...     ...     ...     ...   ...  ...    ...
# 3664658              0         서울       0  2505.0  2481.0  24.0  0.0    0.0
# 3664659              1         서울       1  2505.0  2481.0  24.0  0.0    0.0
# 3664660              1         서울       1  2505.0  2481.0  24.0  0.0    0.0
# 3664661              1         서울       1  2505.0  2481.0  24.0  0.0    0.0
# 3664662              1         서울       1  2505.0  2481.0  24.0  0.0    0.0
#
# [3611140 rows x 20 columns]

# %% [markdown]
# ### 삭제완료

# %%
len(d_org_df) == len(org_hall_df) - len(masking)
# Out:
# True

# %% [markdown]
# # 컬럼명 수정
# ### d_org_df로 수정함

# %% [markdown]
# - PBLPRFR_NM : 공연이름
# - PBLPRFR_PLACE_NM : 공연장소
# - PBLPRFR_DE : 공연날짜
# - PBLPRFR_TIME : 공연시간
# - GENRE_NM : 장르
# - PRC_CN : 가격대
# - SETLE_DE : 구매날짜
# - SETLE_TIME : 구매시간
# - DSCNT_CN : 할인정보
# - SETLE_PRICE : 구매가격
# - MBER_GRAD_NM : 회원등급
# - BN_VALUE : 나이
# - SEXDSTN_VALUE : 성별
# - OC_AREA_NM : 거주지
# - RFN_AT : 환불여부

# %%
d_org_df = d_org_df.rename(columns={'PBLPRFR_NM': '공연이름'})
d_org_df = d_org_df.rename(columns={'PBLPRFR_PLACE_NM': '공연장소'})
d_org_df = d_org_df.rename(columns={'PBLPRFR_DE': '공연날짜'})
d_org_df = d_org_df.rename(columns={'PBLPRFR_TIME': '공연시간'})
d_org_df = d_org_df.rename(columns={'GENRE_NM': '장르'})
d_org_df = d_org_df.rename(columns={'PRC_CN': '가격대'})
d_org_df = d_org_df.rename(columns={'SETLE_DE': '구매날짜'})
d_org_df = d_org_df.rename(columns={'SETLE_TIME': '구매시간'})
d_org_df = d_org_df.rename(columns={'DSCNT_CN': '할인정보'})
d_org_df = d_org_df.rename(columns={'SETLE_PRICE': '구매가격'})
d_org_df = d_org_df.rename(columns={'MBER_GRAD_NM': '회원등급'})
d_org_df = d_org_df.rename(columns={'BN_VALUE': '나이'})
d_org_df = d_org_df.rename(columns={'SEXDSTN_VALUE': '성별'})
d_org_df = d_org_df.rename(columns={'OC_AREA_NM': '거주지'})
d_org_df = d_org_df.rename(columns={'RFN_AT': '환불여부'})
d_org_df.head()
# Out:
#                          공연이름  공연장소       공연날짜    공연시간  장르  \
# 0  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21  193000  합창
# 1  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21  193000  합창
# 2  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21  193000  합창
# 3  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21  193000  합창
# 4  국립합창단 창단 50주년 기념 <한국합창교향곡>  콘서트홀 2023-03-21  193000  합창
#
#                                  가격대      구매날짜    구매시간        할인정보     구매가격  \
# 0  R석 30000원 / S석 20000원 / A석 10000원  20230308   70000       기타 할인  24000.0
# 1  R석 30000원 / S석 20000원 / A석 10000원  20230221  190000       기타 할인  10000.0
# 2  R석 30000원 / S석 20000원 / A석 10000원  20230228   10000       기타 할인   8000.0
# 3  R석 30000원 / S석 20000원 / A석 10000원  20230226  100000       기타 할인  24000.0
# 4  R석 30000원 / S석 20000원 / A석 10000원  20230320  230000  골드회원 할인40%  18000.0
#
#   회원등급  나이  성별 거주지  환불여부    총판매석   일반판매석  장애인석  OP석  판매유보석
# 0   무료  50   1  경기     0  2505.0  2481.0  24.0  0.0    0.0
# 1   블루  60   0  서울     0  2505.0  2481.0  24.0  0.0    0.0
# 2   무료  60   0  서울     0  2505.0  2481.0  24.0  0.0    0.0
# 3   무료  40   0  서울     0  2505.0  2481.0  24.0  0.0    0.0
# 4   골드  60   1  서울     0  2505.0  2481.0  24.0  0.0    0.0

# %% [markdown]
# - 우선 csv로 저장후 다른코랩에서 진행
# - 램이 너무 무거워짐

# %%
file_save = DATA_PATH + 'first_refine.csv'
d_org_df.to_csv(file_save, index=False)
